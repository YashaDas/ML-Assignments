# %% [markdown]
# ### ML Assignment_12

# %% [markdown]
# #### 1. What is prior probability? Give an example.

# %% [markdown]
# __Ans:__ Prior probability shows the likelihood of an outcome in a given dataset. For example, in the mortgage case, ``P(Y)`` is the default rate on a home mortgage, which is ``2%``. ``P(Y|X)`` is called the conditional probability, which provides the probability of an outcome given the evidence, that is, when the value of ``X`` is known.
#
# ![ml%20assignment_12%20q1.png](attachment:ml%20assignment_12%20q1.png)

# %% [markdown]
# #### 2. What is posterior probability? Give an example.

# %% [markdown]
# __Ans:__ Posterior probability is a revised probability that takes into account new available information. For example, let there be two urns, urn ``A`` having 5 black balls and 10 red balls and urn ``B`` having 10 black balls and 5 red balls.
#
# ![ml%20assignment_12%20q1.png](attachment:ml%20assignment_12%20q1.png)

# %% [markdown]
# #### 3. What is likelihood probability? Give an example.

# %% [markdown]
# __Ans:__ Likelihood Function in Machine Learning and Data Science is the joint probability distribution(jpd) of the dataset given as a function of the parameter. Think of it as the probability of obtaining the observed data given the parameter values.
#
# ![ml%20assignment_12%20q3.png](attachment:ml%20assignment_12%20q3.png)

# %% [markdown]
# #### 4. What is Naïve Bayes classifier? Why is it named so?

# %% [markdown]
# __Ans:__ Naive Bayes is a simple and powerful algorithm for predictive modeling. Naive Bayes is called naive because it assumes that each input variable is independent. This is a strong assumption and unrealistic for real data; however, the technique is very effective on a large range of complex problems.
#
# ![ml%20assignment_12%20q4.jpeg](attachment:ml%20assignment_12%20q4.jpeg)

# %% [markdown]
# #### 5. What is optimal Bayes classifier?

# %% [markdown]
# __Ans:__ The Optimal Bayes Classifier is a probabilistic model that makes the most probable prediction for a new example. Optimal Bayes Classifier is a probabilistic model that finds the most probable prediction using the training data and space of hypotheses to make a prediction for a new data instance.
#
# ![ml%20assignment_12%20q5.png](attachment:ml%20assignment_12%20q5.png)

# %% [markdown]
# #### 6. Write any two features of Bayesian learning methods.

# %% [markdown]
# __Ans:__ Some of the features of Bayesian Learning Methods are __:__
#
# - A probability distribution over observed data for each possible hypothesis.
# - New instances can be classified by combining the predictions of multiple hypotheses, weighted by their probabilities.
# ![ml%20assignment_12%20q6.jpeg](attachment:ml%20assignment_12%20q6.jpeg)

# %% [markdown]
# #### 7. Define the concept of consistent learners.

# %% [markdown]
# __Ans:__ ___Consistent Learners:___ A learner ``L`` using a hypothesis ``H`` and training data ``D`` is said to be a consistent learner if it always outputs a hypothesis with zero error on ``D`` whenever ``H`` contains such a hypothesis. _By definition, a consistent learner must produce a hypothesis in the version space for ``H`` given ``D``._
#
# ![ml%20assignment_12%20q7.jpeg](attachment:ml%20assignment_12%20q7.jpeg)

# %% [markdown]
# #### 8. Write any two strengths of Bayes classifier.

# %% [markdown]
# __Ans:__ Some of the strengths of the Bayes Classifer are __:__
#
# - This algorithm works quickly and can save a lot of time.
# - Naive Bayes is suitable for solving multi-class prediction problems.
# - If its assumption of the independence of features holds true, it can perform better than other models and requires much less training data.
# - It is simple and easy to implement.
# - It doesn't require as much training data.
# - It handles both continuous and discrete data.
# - It is highly scalable with the number of predictors and data points.
# - It is fast and can be used to make real-time predictions.

# %% [markdown]
# #### 9. Write any two weaknesses of Bayes classifier.

# %% [markdown]
# __Ans:__ Some of the weaknesses of the Bayes Classifer are __:__
#
# - The greatest weakness of the naïve Bayes classifier is that it relies on an often-faulty assumption of equally important and independent features which results in biased posterior probabilities.
# - If your test data set has a categorical variable of a category that wasn’t present in the training data set, the Naive Bayes model will assign it zero probability and won’t be able to make any predictions in this regard. This phenomenon is called ‘Zero Frequency,’ and you’ll have to use a smoothing technique to solve this problem.
# - This algorithm is also notorious as a lousy estimator. So, you shouldn’t take the probability outputs of ‘predict_proba’ too seriously.
# - It assumes that all the features are independent. While it might sound great in theory, in real life, you’ll hardly find a set of independent features.

# %% [markdown]
# #### 10. Explain how Naïve Bayes classifier is used for -
#
#     1. Text classification
#     2. Spam filtering
#     3. Market sentiment analysis

# %% [markdown]
# __Ans:__ Navie Bayes Classifier is used for -
#
# - __Text classification:__ The Naive Bayes classifier is a simple classifier that classifies based on probabilities of events. It is the applied commonly to text classification. With the training set, we can train a Naive Bayes classifier which we can use to automaticall categorize a new sentence.
#
# - __Spam filtering:__ Naive Bayes classifiers work by correlating the use of tokens (typically words, or sometimes other things), with spam and non-spam e-mails and then using Bayes' theorem to calculate a probability that an email is or is not spam. It is one of the oldest ways of doing spam filtering, with roots in the 1990s.
#
# - __Market sentiment analysis:__ Market Sentiment analysis is a field dedicated to extracting subjective emotions and feelings from text. One common use of sentiment analysis is to figure out if a text expresses negative or positive feelings. Naive Bayes is a popular algorithm for classifying text.
